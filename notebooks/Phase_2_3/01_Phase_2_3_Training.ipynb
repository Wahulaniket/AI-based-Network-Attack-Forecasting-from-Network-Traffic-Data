# %% [markdown]
# # CyberCast
# ## Phase 2.3
# ### Experiment / Training
#
# **This notebook documents the FINAL FROZEN Phase 2.3 experiment.**
# *(Do not rerun the final blind test here.)*

# %%
import os
os.chdir('../..')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Feature Recovery and Audit
# - SET_R = 89 features
# - SET_R_SELECT = 40 features
# - SET_A = 15 features
# - Six rejected columns: Timestamp, binary_attack, dominant_label, attack_ratio, attack_flow_count, has_traffic

# %%
feat_comp = 'results/phase2_3/feature_comparison.csv'
if os.path.exists(feat_comp):
    print("Stage 1 Feature Comparison:")
    display(pd.read_csv(feat_comp))
# Out:
# Stage 1 Feature Comparison:
#          Config  History_Windows  Feature_Count  Val_PR_AUC  Val_ROC_AUC  \
# 0         SET_A               20             15    0.470327     0.678150
# 1         SET_R               20             89    0.627856     0.741611
# 2  SET_R_SELECT               20             40    0.529652     0.745192
#
#      Val_F1  Val_Precision  Val_Recall  Best_Epoch  \
# 0  0.440541       0.670782    0.327968           4
# 1  0.613909       0.759644    0.515091           0
# 2  0.571429       0.668464    0.498994           1
#
#                                   Model_Path
# 0         models/phase2_3\model_SET_A_h20.pt
# 1         models/phase2_3\model_SET_R_h20.pt
# 2  models/phase2_3\model_SET_R_SELECT_h20.pt

# %%
hist_comp = 'results/phase2_3/history_comparison.csv'
if os.path.exists(hist_comp):
    print("Stage 2 History Comparison:")
    display(pd.read_csv(hist_comp))
# Out:
# Stage 2 History Comparison:
#   Config  History_Windows  Feature_Count  Val_PR_AUC  Val_ROC_AUC    Val_F1  \
# 0  SET_R                5             89    0.541435     0.689298  0.549237
# 1  SET_R               10             89    0.585122     0.691421  0.600529
# 2  SET_R               20             89    0.608077     0.748342  0.569501
# 3  SET_R               30             89    0.555868     0.730027  0.522199
#
#    Val_Precision  Val_Recall  Best_Epoch                          Model_Path
# 0       0.883929    0.398390           3   models/phase2_3\model_SET_R_h5.pt
# 1       0.876448    0.456740           2  models/phase2_3\model_SET_R_h10.pt
# 2       0.864754    0.424547           1  models/phase2_3\model_SET_R_h20.pt
# 3       0.550111    0.496982           0  models/phase2_3\model_SET_R_h30.pt

# %% [markdown]
# ### Final Champion Selection
# - SET_R (89 features)
# - 20 windows (200 seconds)
# - LSTM
# - threshold = 0.9830
#
# ### Reproducibility
# Run 1 = 0.6471 (Best epoch 0)
# Run 2 = 0.6471 (Best epoch 0)
#
# *Reproducible under the tested software/hardware environment with the specified seed controls.*
#
# **RESULT STATUS:** FROZEN RESULT
