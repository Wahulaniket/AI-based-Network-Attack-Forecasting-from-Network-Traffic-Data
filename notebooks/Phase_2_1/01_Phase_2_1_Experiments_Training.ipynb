# %% [markdown]
# # CyberCast
# ## Phase 2.1
# ### Experiment / Training

# %%
import os
os.chdir('../..')
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1-5. Objective and Configuration
# Phase 2.1 explored class weights, loss functions, and architectural modifications to stabilize training.

# %% [markdown]
# ### 6-8. Experiment Comparison and Winner Selection
# Actual validation configuration winner:
# - Base LSTM 64
# - pos_weight = 4.0
# - Validation PR-AUC = 0.5087
# - Validation F1 = 0.3727

# %%
exp_path = 'results/phase2_1/experiment_comparison.csv'
if os.path.exists(exp_path):
    df = pd.read_csv(exp_path)
    display(df)
else:
    print("Experiment comparison artifact unavailable.")
# Out:
#              Config  Params  Val_PR_AUC    Val_F1  Val_Precision  Val_Recall  \
# 0         E1_pw=4.0   56129    0.508715  0.372662       0.723464    0.250969
# 1     E2_BCE_bestpw   56129    0.508715  0.372662       0.723464    0.250969
# 2     E3_LSTM_64_32   33313    0.507181  0.312112       0.785156    0.194767
# 3       E2_Focal_g1   56129    0.506879  0.351729       0.730887    0.231589
# 4        E1_pw=5.19   56129    0.504205  0.397386       0.610442    0.294574
# 5         E1_pw=3.0   56129    0.503784  0.307080       0.857778    0.187016
# 6        E1_pw=auto   56129    0.503662  0.397126       0.609218    0.294574
# 7       E2_Focal_g2   56129    0.503276  0.351391       0.718563    0.232558
# 8     E3_LSTM_LNorm   56257    0.502369  0.375676       0.620536    0.269380
# 9      E3_LSTM_Attn   22914    0.502112  0.231293       0.944444    0.131783
# 10   E3_LSTM_128_64  123969    0.501906  0.321839       0.769231    0.203488
# 11        E1_pw=2.0   56129    0.495727  0.180227       0.927928    0.099806
# 12  E2_BCE_noweight   56129    0.495004  0.087118       1.000000    0.045543
# 13        E1_pw=1.0   56129    0.494873  0.153298       0.955556    0.083333
# 14     E3_LSTM_Skip   24001    0.479142  0.252267       0.845304    0.148256
#
#     Val_ROC_AUC  Val_Accuracy  Best_Epoch  Epochs_Trained   Val_FPR   Val_FNR
# 0      0.692119      0.797020           1              11  0.030331  0.749031
# 1      0.692119      0.797020           1              11  0.030331  0.749031
# 2      0.695475      0.793762           1              11  0.016850  0.805233
# 3      0.693478      0.794926           1              11  0.026961  0.768411
# 4      0.689991      0.785382           1              11  0.059436  0.705426
# 5      0.692299      0.797253           1              11  0.009804  0.812984
# 6      0.690621      0.785149           1              11  0.059743  0.705426
# 7      0.692830      0.793762           1              11  0.028799  0.767442
# 8      0.693065      0.784916           1              11  0.052083  0.730620
# 9      0.692186      0.789572           1              11  0.002451  0.868217
# 10     0.695484      0.793994           1              11  0.019301  0.796512
# 11     0.694322      0.781890           1              11  0.002451  0.900194
# 12     0.698413      0.770717           1              11  0.000000  0.954457
# 13     0.691020      0.778864           1              11  0.001225  0.916667
# 14     0.664461      0.788873           1              11  0.008578  0.851744

# %% [markdown]
# ### 9-10. Locked Threshold and Artifacts
# Locked threshold = 0.19
#
# **RESULT STATUS:** HISTORICAL RESULT
