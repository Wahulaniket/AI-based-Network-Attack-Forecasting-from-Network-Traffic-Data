# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().parent
RAW_DIR = PROJECT_ROOT / "data" / "raw"

csv_files = list(RAW_DIR.glob("*.csv"))

print("Project root:", PROJECT_ROOT)
print("CSV files found:")

for f in csv_files:
    print(" -", f.name)
# Out:
# Project root: d:\working_projects\SIH\cyberCast
# CSV files found:
#  - Friday-02-03-2018_TrafficForML_CICFlowMeter.csv

# %%
csv_path = csv_files[0]

print("Using:", csv_path)
# Out:
# Using: d:\working_projects\SIH\cyberCast\data\raw\Friday-02-03-2018_TrafficForML_CICFlowMeter.csv

# %%
df_sample = pd.read_csv(csv_path, nrows=5)

print("Sample shape:", df_sample.shape)
print("\nColumns:")
for i, col in enumerate(df_sample.columns):
    print(i, col)
# Out:
# Sample shape: (5, 80)
#
# Columns:
# 0 Dst Port
# 1 Protocol
# 2 Timestamp
# 3 Flow Duration
# 4 Tot Fwd Pkts
# 5 Tot Bwd Pkts
# 6 TotLen Fwd Pkts
# 7 TotLen Bwd Pkts
# 8 Fwd Pkt Len Max
# 9 Fwd Pkt Len Min
# 10 Fwd Pkt Len Mean
# 11 Fwd Pkt Len Std
# 12 Bwd Pkt Len Max
# 13 Bwd Pkt Len Min
# 14 Bwd Pkt Len Mean
# 15 Bwd Pkt Len Std
# 16 Flow Byts/s
# 17 Flow Pkts/s
# 18 Flow IAT Mean
# 19 Flow IAT Std
# 20 Flow IAT Max
# 21 Flow IAT Min
# 22 Fwd IAT Tot
# 23 Fwd IAT Mean
# 24 Fwd IAT Std
# 25 Fwd IAT Max
# 26 Fwd IAT Min
# 27 Bwd IAT Tot
# 28 Bwd IAT Mean
# 29 Bwd IAT Std
# 30 Bwd IAT Max
# 31 Bwd IAT Min
# 32 Fwd PSH Flags
# 33 Bwd PSH Flags
# 34 Fwd URG Flags
# 35 Bwd URG Flags
# 36 Fwd Header Len
# 37 Bwd Header Len
# 38 Fwd Pkts/s
# 39 Bwd Pkts/s
# 40 Pkt Len Min
# 41 Pkt Len Max
# 42 Pkt Len Mean
# 43 Pkt Len Std
# 44 Pkt Len Var
# 45 FIN Flag Cnt
# 46 SYN Flag Cnt
# 47 RST Flag Cnt
# 48 PSH Flag Cnt
# 49 ACK Flag Cnt
# 50 URG Flag Cnt
# 51 CWE Flag Count
# 52 ECE Flag Cnt
# 53 Down/Up Ratio
# 54 Pkt Size Avg
# 55 Fwd Seg Size Avg
# 56 Bwd Seg Size Avg
# 57 Fwd Byts/b Avg
# 58 Fwd Pkts/b Avg
# 59 Fwd Blk Rate Avg
# 60 Bwd Byts/b Avg
# 61 Bwd Pkts/b Avg
# 62 Bwd Blk Rate Avg
# 63 Subflow Fwd Pkts
# 64 Subflow Fwd Byts
# 65 Subflow Bwd Pkts
# 66 Subflow Bwd Byts
# 67 Init Fwd Win Byts
# 68 Init Bwd Win Byts
# 69 Fwd Act Data Pkts
# 70 Fwd Seg Size Min
# 71 Active Mean
# 72 Active Std
# 73 Active Max
# 74 Active Min
# 75 Idle Mean
# 76 Idle Std
# 77 Idle Max
# 78 Idle Min
# 79 Label

# %%
df_sample.head()
# Out:
#    Dst Port  Protocol            Timestamp  Flow Duration  Tot Fwd Pkts  \
# 0       443         6  02/03/2018 08:47:38         141385             9
# 1     49684         6  02/03/2018 08:47:38            281             2
# 2       443         6  02/03/2018 08:47:40         279824            11
# 3       443         6  02/03/2018 08:47:40            132             2
# 4       443         6  02/03/2018 08:47:41         274016             9
#
#    Tot Bwd Pkts  TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  \
# 0             7              553             3773              202
# 1             1               38                0               38
# 2            15             1086            10527              385
# 3             0                0                0                0
# 4            13             1285             6141              517
#
#    Fwd Pkt Len Min  ...  Fwd Seg Size Min  Active Mean  Active Std  \
# 0                0  ...                20            0           0
# 1                0  ...                20            0           0
# 2                0  ...                20            0           0
# 3                0  ...                20            0           0
# 4                0  ...                20            0           0
#
#    Active Max  Active Min  Idle Mean  Idle Std  Idle Max  Idle Min   Label
# 0           0           0          0         0         0         0  Benign
# 1           0           0          0         0         0         0  Benign
# 2           0           0          0         0         0         0  Benign
# 3           0           0          0         0         0         0  Benign
# 4           0           0          0         0         0         0  Benign
#
# [5 rows x 80 columns]

# %%
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 80 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Dst Port           5 non-null      int64
#  1   Protocol           5 non-null      int64
#  2   Timestamp          5 non-null      object
#  3   Flow Duration      5 non-null      int64
#  4   Tot Fwd Pkts       5 non-null      int64
#  5   Tot Bwd Pkts       5 non-null      int64
#  6   TotLen Fwd Pkts    5 non-null      int64
#  7   TotLen Bwd Pkts    5 non-null      int64
#  8   Fwd Pkt Len Max    5 non-null      int64
#  9   Fwd Pkt Len Min    5 non-null      int64
#  10  Fwd Pkt Len Mean   5 non-null      float64
#  11  Fwd Pkt Len Std    5 non-null      float64
#  12  Bwd Pkt Len Max    5 non-null      int64
#  13  Bwd Pkt Len Min    5 non-null      int64
#  14  Bwd Pkt Len Mean   5 non-null      float64
#  15  Bwd Pkt Len Std    5 non-null      float64
#  16  Flow Byts/s        5 non-null      float64
#  17  Flow Pkts/s        5 non-null      float64
#  18  Flow IAT Mean      5 non-null      float64
#  19  Flow IAT Std       5 non-null      float64
#  20  Flow IAT Max       5 non-null      int64
#  21  Flow IAT Min       5 non-null      int64
#  22  Fwd IAT Tot        5 non-null      int64
#  23  Fwd IAT Mean       5 non-null      float64
#  24  Fwd IAT Std        5 non-null      float64
#  25  Fwd IAT Max        5 non-null      int64
#  26  Fwd IAT Min        5 non-null      int64
#  27  Bwd IAT Tot        5 non-null      int64
#  28  Bwd IAT Mean       5 non-null      float64
#  29  Bwd IAT Std        5 non-null      float64
#  30  Bwd IAT Max        5 non-null      int64
#  31  Bwd IAT Min        5 non-null      int64
#  32  Fwd PSH Flags      5 non-null      int64
#  33  Bwd PSH Flags      5 non-null      int64
#  34  Fwd URG Flags      5 non-null      int64
#  35  Bwd URG Flags      5 non-null      int64
#  36  Fwd Header Len     5 non-null      int64
#  37  Bwd Header Len     5 non-null      int64
#  38  Fwd Pkts/s         5 non-null      float64
#  39  Bwd Pkts/s         5 non-null      float64
#  40  Pkt Len Min        5 non-null      int64
#  41  Pkt Len Max        5 non-null      int64
#  42  Pkt Len Mean       5 non-null      float64
#  43  Pkt Len Std        5 non-null      float64
#  44  Pkt Len Var        5 non-null      float64
#  45  FIN Flag Cnt       5 non-null      int64
#  46  SYN Flag Cnt       5 non-null      int64
#  47  RST Flag Cnt       5 non-null      int64
#  48  PSH Flag Cnt       5 non-null      int64
#  49  ACK Flag Cnt       5 non-null      int64
#  50  URG Flag Cnt       5 non-null      int64
#  51  CWE Flag Count     5 non-null      int64
#  52  ECE Flag Cnt       5 non-null      int64
#  53  Down/Up Ratio      5 non-null      int64
#  54  Pkt Size Avg       5 non-null      float64
#  55  Fwd Seg Size Avg   5 non-null      float64
#  56  Bwd Seg Size Avg   5 non-null      float64
#  57  Fwd Byts/b Avg     5 non-null      int64
#  58  Fwd Pkts/b Avg     5 non-null      int64
#  59  Fwd Blk Rate Avg   5 non-null      int64
#  60  Bwd Byts/b Avg     5 non-null      int64
#  61  Bwd Pkts/b Avg     5 non-null      int64
#  62  Bwd Blk Rate Avg   5 non-null      int64
#  63  Subflow Fwd Pkts   5 non-null      int64
#  64  Subflow Fwd Byts   5 non-null      int64
#  65  Subflow Bwd Pkts   5 non-null      int64
#  66  Subflow Bwd Byts   5 non-null      int64
#  67  Init Fwd Win Byts  5 non-null      int64
#  68  Init Bwd Win Byts  5 non-null      int64
#  69  Fwd Act Data Pkts  5 non-null      int64
#  70  Fwd Seg Size Min   5 non-null      int64
#  71  Active Mean        5 non-null      int64
#  72  Active Std         5 non-null      int64
#  73  Active Max         5 non-null      int64
#  74  Active Min         5 non-null      int64
#  75  Idle Mean          5 non-null      int64
#  76  Idle Std           5 non-null      int64
#  77  Idle Max           5 non-null      int64
#  78  Idle Min           5 non-null      int64
#  79  Label              5 non-null      object
# dtypes: float64(20), int64(58), object(2)
# memory usage: 3.3+ KB

# %%
cd ..
# Out:
# d:\working_projects\SIH\cyberCast

# %%
cd data/raw/
# Out:
# d:\working_projects\SIH\cyberCast\data\raw

# %%
# !kaggle datasets download -d solarmainframe/ids-intrusion-csv

# %%
# !unzip ids-intrusion-csv.zip
